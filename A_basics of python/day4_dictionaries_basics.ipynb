# %%
# create dictionary 
star = {"name":"sun",
        "mass":1.0,
        "temperature":5778,
        "type":"g-type"}

print(star["name"])
print(star["mass"])

#add new key
star["radius"]=2.0
print(star)

#loops through dictinory 
for key in star:
    print(key)

for value in star.items():
    print(value)
supernova = {
    "name": "SN1998aq",
    "redshift": 0.0037,
    "apparent_magnitude": 12.5,
    "absolute_magnitude": -19.3
}

print(supernova)

# 9. Access specific value
print("Redshift =", supernova["redshift"])

# 10. Compute distance modulus (simple)
distance_modulus = supernova["apparent_magnitude"] - supernova["absolute_magnitude"]
print("Distance Modulus =", distance_modulus)
# Out:
# sun
# 1.0
# {'name': 'sun', 'mass': 1.0, 'temperature': 5778, 'type': 'g-type', 'radius': 2.0}
# name
# mass
# temperature
# type
# radius
# ('name', 'sun')
# ('mass', 1.0)
# ('temperature', 5778)
# ('type', 'g-type')
# ('radius', 2.0)
# {'name': 'SN1998aq', 'redshift': 0.0037, 'apparent_magnitude': 12.5, 'absolute_magnitude': -19.3}
# Redshift = 0.0037
# Distance Modulus = 31.8
