# %%
numbers = [1,2,3,4,5,6]

squared = []
for n in numbers:
    squared.append(n**2)

print(squared)
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
import numpy as np 
numbers = np.array([1,2,3,4,5])
print(numbers**2)
# Out:
# [ 1  4  9 16 25]

# %%
import time 
start = time.time()
arr = np.arange(1000000)
arr_squared = arr*2
end = time.time()
print("numpy time:",end - start)
# Out:
# numpy time: 0.007342815399169922

# %%
x = np.linspace(0,10,1000)
y = x**2

area = np.trapezoid(y,x)
print("numerical integral:",area)
# Out:
# numerical integral: 333.333500333834
